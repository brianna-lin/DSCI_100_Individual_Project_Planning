# %% [markdown]
# # Individual Project Planning Assignment

# %% [markdown]
# ## 1) Data Description

# %%
library(repr)
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
players_data <- read_csv("https://drive.google.com/uc?export=download&id=1Mw9vW0hjTJwRWx0bDXiSpYsO3gKogaPz")
players_data
# Out:
# Rows: 196 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, age
# lgl (3): subscribe, individualId, organizationName
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     experience subscribe
# 1   Pro         TRUE
# 2   Veteran     TRUE
# 3   Veteran    FALSE
# 4   Amateur     TRUE
# 5   Regular     TRUE
# 6   Amateur     TRUE
# 7   Regular     TRUE
# 8   Amateur    FALSE
# 9   Amateur     TRUE
# 10  Veteran     TRUE
# 11  Veteran     TRUE
# 12  Pro         TRUE
# 13  Beginner    TRUE
# 14  Amateur     TRUE
# 15  Veteran     TRUE
# 16  Amateur    FALSE
# 17  Beginner    TRUE
# 18  Amateur     TRUE
# 19  Amateur     TRUE
# 20  Regular     TRUE
# 21  Regular     TRUE
# 22  Amateur    FALSE
# 23  Beginner    TRUE
# 24  Beginner    TRUE
# ...

# %% [markdown]
# By looking at the data sets above of the players and sessions, we can see that for the players data set, there are 196 observations and 7 variables (experience level, whether the player is a subscriber, their hashed email, number of hours played, the player’s name, their gender, and their age), excluding the columns individualId and organizationName which only contain NA. The data is tidy as each column corresponds to a single variable, each observation forms a row, and each cell contains a single value.
#
# A potential issue with the data is that some of the values in the columns may contain NA, which would cause problems when wrangling and analyzing. Unseen issues could include bias from how the data was collected, since there is only information on players who voluntarily joined the survey and not on MineCraft players as a whole. Furthermore, for the players' age and experience, we do not know how this information was obtained - if it was self-reported, we do not know how reliable that information is.

# %% [markdown]
# #### Summary Statistics

# %%
summary(players_data)
# Out:
#   experience        subscribe       hashedEmail         played_hours
#  Length:196         Mode :logical   Length:196         Min.   :  0.000
#  Class :character   FALSE:52        Class :character   1st Qu.:  0.000
#  Mode  :character   TRUE :144       Mode  :character   Median :  0.100
#                                                        Mean   :  5.846
#                                                        3rd Qu.:  0.600
#                                                        Max.   :223.100
#      name              gender               age        individualId
#  Length:196         Length:196         Min.   : 8.00   Mode:logical
#  Class :character   Class :character   1st Qu.:17.00   NA's:196
#  Mode  :character   Mode  :character   Median :19.00
#                                        Mean   :21.28
#                                        3rd Qu.:22.00
#                                        Max.   :99.00
#  organizationName
#  Mode:logical
#  NA's:196

# %%
player_genders <- players_data |>
    group_by(gender) |>
    summarize(count = n())
player_experience <- players_data |>
    group_by(experience) |>
    summarize(count = n())
player_subscribers <- players_data |>
    group_by(subscribe) |>
    summarize(count = n())
player_genders
player_experience
player_subscribers
# Out:
#   gender            count
# 1 Agender             2
# 2 Female             37
# 3 Male              124
# 4 Non-binary         15
# 5 Other               1
# 6 Prefer not to say  11
# 7 Two-Spirited        6
#   experience count
# 1 Amateur    63
# 2 Beginner   35
# 3 Pro        14
# 4 Regular    36
# 5 Veteran    48
#   subscribe count
# 1 FALSE      52
# 2  TRUE     144

# %% [markdown]
# By observing the statistics above, we can see that for this data set, there are more subscribers than non-subscribers, most players are amateur level, and most are male. We also know that the max age of the players is 99 while the mean is 21.28 years old. The max number of hours played is 223.10 while the mean is 5.85 hours.
#
# Another issue that can be identified from the statistics above is that if we were to use the data for a classification problem, some of the variables in this dataset exhibit oversampling (e.g. more data on male players than other gender players), which would lower the accuracy of a KNN classification model.

# %%
experience_summary <- players_data |>
    group_by(experience) |>
    summarise(avg_played_hrs = mean(played_hours, na.rm = TRUE), max_hrs_played = max(played_hours, na.rm = TRUE),
              avg_age = mean(age, na.rm = TRUE), max_age = max(age, na.rm = TRUE))

subscriber_summary <- players_data |>
    group_by(subscribe) |>
    summarise(avg_played_hrs = mean(played_hours, na.rm = TRUE), max_hrs_played = max(played_hours, na.rm = TRUE),
              avg_age = mean(age, na.rm = TRUE), max_age = max(age, na.rm = TRUE))

gender_summary <- players_data |>
    group_by(gender) |>
    summarise(avg_played_hrs = mean(played_hours, na.rm = TRUE), max_hrs_played = max(played_hours, na.rm = TRUE),
              avg_age = mean(age, na.rm = TRUE), max_age = max(age, na.rm = TRUE))

experience_summary
subscriber_summary
gender_summary
# Out:
#   experience avg_played_hrs max_hrs_played avg_age  max_age
# 1 Amateur     6.0174603     150.0          20.25397 45
# 2 Beginner    1.2485714      23.7          21.65714 42
# 3 Pro         2.6000000      30.3          22.21429 91
# 4 Regular    18.2083333     223.1          22.77778 99
# 5 Veteran     0.6479167      12.5          20.95833 46
#   subscribe avg_played_hrs max_hrs_played avg_age  max_age
# 1 FALSE     0.5019231        7.1          22.98077 50
# 2  TRUE     7.7756944      223.1          20.66667 99
#   gender            avg_played_hrs max_hrs_played avg_age  max_age
# 1 Agender            6.25000000     12.5          23.50000 27
# 2 Female            10.63513514    178.2          21.81081 44
# 3 Male               4.12741935    223.1          20.20968 50
# 4 Non-binary        14.88000000    218.1          19.06667 25
# 5 Other              0.20000000      0.2          91.00000 91
# 6 Prefer not to say  0.37272727      2.0          21.36364 33
# ...

# %% [markdown]
# | Player Status | Average Number of Hours Played | Highest Number of Hours Played | Average Age | Highest Age |
# |----------------|--------------------------------|--------------------------------|-------------| ------------|
# | Subscribed | 7.78 | 223.1 | 20.67 | 99 |
# | Not Subscribed | 0.5 | 7.1 | 22.98 | 50 |
# | Amateur | 6.02 | 150 | 20.25 | 45 |
# | Beginner | 1.25 | 23.7 | 21.66 | 42 |
# | Pro | 2.6 | 30.3 | 22.21 | 91 |
# | Regular | 18.21 | 223.1 | 22.78 | 99 |
# | Veteran | 0.65 | 12.5 | 20.96 | 46 |

# %% [markdown]
# | Player Gender | Average Number of Hours Played | Highest Number of Hours Played | Average Age | Highest Age |
# |-------------------|--------------------------------|--------------------------------|-------------|-------------|
# | Agender | 6.25 | 12.5 | 23.5 | 27 |
# | Female | 10.64 | 178.2 | 21.81 | 44 |
# | Male | 4.13 | 223.1 | 20.21 | 50 |
# | Non-binary | 14.88 | 218.1 | 19.07 | 25 |
# | Other | 0.2 | 0.2 | 91 | 91 |
# | Prefer Not To Say | 0.37 | 2 | 21.36 | 33 |
# | Two-Spirited | 0.08 | 0.4 | 33.17 | 99 |

# %% [markdown]
# From the tables of summary statistics above, we can see that subscribers and regular level players play the most, while non-subscribers and veteran level players play the least. The average age appears to be about the same across all types of players (20 - 23), so age does not appear to change/differ with a player's subscription status and experience. We can also see that male players have the highest number of hours played while non-binary players have the highest average played hours. Average age fluctuates a bit more for player gender, ranging from 20 - 91.

# %% [markdown]
# ### 2) Questions

# %% [markdown]
# The question I selected for this project was Question 2 below.
#
# **Broad Question (Q2):** What “kinds” of players are most likely to contribute a large amount of data?
#
# **Specific (Data Analysis) Question:** Can the experience level, subscription status, and age of a player predict the number of hours of MineCraft they have played in the players data set?

# %% [markdown]
# The data will help me address my question of interest as I can use the experience, subscribe, and age variables in the data set to predict on the played_hours variable. Because the players data is already tidy, there is no need to wrangle it before the analysis.

# %% [markdown]
# ### 3) Exploratory Data Analysis and Visualization

# %%
# as shown at the beginning, this data set is loadable into R:
head(players_data)
# Out:
#   experience subscribe
# 1 Pro         TRUE
# 2 Veteran     TRUE
# 3 Veteran    FALSE
# 4 Amateur     TRUE
# 5 Regular     TRUE
# 6 Amateur     TRUE
#   hashedEmail                                                      played_hours
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d 30.3
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9  3.8
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28  0.0
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5  0.7
# 5 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e  0.1
# 6 f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977  0.0
#   name      gender age individualId organizationName
# 1 Morgan    Male    9  NA           NA
# 2 Christian Male   17  NA           NA
# 3 Blake     Male   17  NA           NA
# 4 Flora     Female 21  NA           NA
# 5 Kylie     Male   21  NA           NA
# 6 Adrian    Female 17  NA           NA

# %% [markdown]
# ### Mean of Quantitative Variables

# %%
mean_of_quant_vars <- players_data |>
    select(played_hours, age) |>
    map_df(mean)
mean_of_quant_vars
# Out:
#   played_hours age
# 1 5.845918     21.28061

# %% [markdown]
# **Table of Mean Quantitative Variables (to two decimal places)**
# | Number of Hours Played | Age |
# |------------------------|-----|
# | 5.85 | 21.28 |

# %%
options(repr.plot.width = 8, repr.plot.height = 8)
played_hrs_distribution <- players_data |>
    ggplot(aes(x = played_hours)) +
        geom_histogram(binwidth = 10, position = "identity") +
        labs(x = "Number of Hours Played", title = "Distribution of Hours Played") +
        theme(text = element_text(size = 18))
played_hrs_distribution
# Out:
# plot without title

# %%
# played hours distribution with different experience levels
played_hrs_grid <- players_data |>
    ggplot(aes(x = played_hours, fill = experience)) +
        geom_histogram(binwidth = 10, position = "identity") +
        facet_grid(rows = vars(experience)) +
        labs(x = "Number of Hours Played", fill = "Experience Level", title = "Distribution of Hours Played") +
        theme(text = element_text(size = 18))
played_hrs_grid
# Out:
# plot without title

# %%
# number of players of each experience level, colored by subscription status
num_players <- players_data |>
    ggplot(aes(x = experience, fill = subscribe)) +
        geom_bar() +
        labs(x = "Experience Level", y = "Number of Players", fill = "Subscriber?",
             title = "Number of Players Based On Experience") +
        theme(text = element_text(size = 18))
num_players

# number of players subscribed vs. not subscribed, colored by experience level
subscriber_experience <- players_data |>
    ggplot(aes(x = subscribe, fill = experience)) +
        geom_bar() +
        labs(x = "Subscribed?", y = "Number of Players", fill = "Experience Level", 
             title = "Number of Subscribed vs. Non-Subscribed Players") +
        theme(text = element_text(size = 18))
subscriber_experience
# Out:
# plot without title
# plot without title

# %%
age_distribution <- players_data |>
    ggplot(aes(x = age, fill = experience)) +
        geom_histogram(binwidth = 5) +
        labs(x = "Age of Player (Years)", y = "Number of Players", fill = "Experience Level",
             title = "Age Distribution of Players") +
        theme(text = element_text(size = 18))
age_distribution
# Out:
# plot without title

# %%
played_hrs_vs_age <- players_data |>
    ggplot(aes(x = age, y = played_hours)) +
        geom_point(alpha = 0.5) +
        labs(x = "Player Age (Years)", y = "Number of Hours Played", title = "Hours Played vs. Age") +
        theme(text = element_text(size = 18))
played_hrs_vs_age
# Out:
# plot without title

# %% [markdown]
# **Insights**
#
# By observing our visualizations, we can deduce that:
# * Players aged around 20 play the most
# * The majority of players, regardless of experience level, are aged between 10 - 25
# * Majority of players, regardless of experience, are subscribers
# * Most players are amateurs or veterans
# * Amateur and regular players play the most; veterans play the least

# %% [markdown]
# ### 4) Methods and Plan

# %% [markdown]
# **Proposed Method:** Multiple Linear Regression
#
# **Explanation**
# * This method is appropriate because
# * Required assumptions:
# * Potential limitations/weaknesses:
# * Comparing and selecting the model:
# * Processing data for application to model:
